# %% [markdown]
# <a href="https://colab.research.google.com/github/harivign/ab_testing-ds1-for-pandas-practice/blob/main/AB_Testing_dataset_for_pandas_practice_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #python pandas practice

# %%
#Calculate the mean and median of Page Views and Time Spent for both groups (A and B)
#Which group has a higher conversion rate? Is the difference significant?
#Group the data by Device and calculate the average Time Spent and Page Views for each device type
#Find the total number of users and the conversion rate for each location.
#Identify users who spent more than 200 seconds on the site and viewed more than 5 pages.

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/ab_testing.csv")  # copy your file path

# %%
df
# Out:
#       User ID Group  Page Views  Time Spent Conversion   Device  \
# 0       14292     B           3         424         No   Mobile
# 1       11682     A           9         342         No   Mobile
# 2       19825     A           2         396         No  Desktop
# 3       16080     B           4         318         No  Desktop
# 4       18851     A           1         338        Yes  Desktop
# ...       ...   ...         ...         ...        ...      ...
# 4995    16360     B          12         313         No   Mobile
# 4996    18084     B          10         313         No  Desktop
# 4997    12063     A          11         156         No  Desktop
# 4998    18647     B          13         346         No  Desktop
# 4999    16686     A          11         208         No  Desktop
#
#               Location
# 0     Northern Ireland
# 1             Scotland
# 2     Northern Ireland
# 3                Wales
# 4             Scotland
# ...                ...
# 4995             Wales
# ...

# %%
df.columns
# Out:
# Index(['User ID', 'Group', 'Page Views', 'Time Spent', 'Conversion', 'Device',
#        'Location'],
#       dtype='object')

# %%
#Calculate the mean and median of Page Views and Time Spent for both groups (A and B)
df["Group"].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
grouped=df.groupby("Group")

# %%
data=grouped[["Page Views","Time Spent"]].agg(["mean","median"])
data
# Out:
#       Page Views         Time Spent
#             mean median        mean median
# Group
# A       7.581580    8.0  241.733227  241.0
# B       7.492946    8.0  243.303910  244.0

# %%
#Which group has a higher conversion rate? Is the difference significant?

# %%
total_yes=df.groupby("Group")["Conversion"].apply(lambda i: (i=="Yes").sum() )

# %%
total_yes
# Out:
# Group
# A    136
# B    349
# Name: Conversion, dtype: int64

# %%
total_user=df.count()
total_user
# Out:
# User ID       5000
# Group         5000
# Page Views    5000
# Time Spent    5000
# Conversion    5000
# Device        5000
# Location      5000
# dtype: int64

# %%
users = df['Group'].value_counts()
users
# Out:
# Group
# A    2519
# B    2481
# Name: count, dtype: int64

# %%
conversion_rate=(total_yes/users)
conversion_rate=conversion_rate*100
conversion_rate
# Out:
# Group
# A     5.398968
# B    14.066909
# dtype: float64

# %%
group_A=conversion_rate["A"]
group_B=conversion_rate["B"]

# %%
output = f"the Group A conversion rate is {group_A:.2f}% and the Group B conversion rate is {group_B:.2f}% "
print(output)
# Out:
# the Group A conversion rate is 5.40% and the Group B conversion rate is 14.07%

# %%
#Group the data by Device and calculate the average Time Spent and Page Views for each device type

# %%
df.groupby("Device")

# %%
df.groupby("Device")[["Time Spent","Page Views"]].mean()
# Out:
#          Time Spent  Page Views
# Device
# Desktop  243.185579    7.530339
# Mobile   241.818846    7.545085

# %%
#Find the total number of users and the conversion rate for each location.

# %%
df
# Out:
#       User ID Group  Page Views  Time Spent Conversion   Device  \
# 0       14292     B           3         424         No   Mobile
# 1       11682     A           9         342         No   Mobile
# 2       19825     A           2         396         No  Desktop
# 3       16080     B           4         318         No  Desktop
# 4       18851     A           1         338        Yes  Desktop
# ...       ...   ...         ...         ...        ...      ...
# 4995    16360     B          12         313         No   Mobile
# 4996    18084     B          10         313         No  Desktop
# 4997    12063     A          11         156         No  Desktop
# 4998    18647     B          13         346         No  Desktop
# 4999    16686     A          11         208         No  Desktop
#
#               Location
# 0     Northern Ireland
# 1             Scotland
# 2     Northern Ireland
# 3                Wales
# 4             Scotland
# ...                ...
# 4995             Wales
# ...

# %%
grouped=df.groupby("Location")
grouped

# %%
convertion=grouped["Conversion"].apply(lambda i : (i=="Yes").sum())
convertion
# Out:
# Location
# England             136
# Northern Ireland    103
# Scotland            125
# Wales               121
# Name: Conversion, dtype: int64

# %%
users_count=grouped["User ID"].count()
users_count
# Out:
# Location
# England             1246
# Northern Ireland    1242
# Scotland            1281
# Wales               1231
# Name: User ID, dtype: int64

# %%
conversion_rate=(convertion/users_count)*100
conversion_rate
# Out:
# Location
# England             10.914928
# Northern Ireland     8.293076
# Scotland             9.758002
# Wales                9.829407
# dtype: float64

# %%
result = pd.DataFrame({
    "Total Users": users_count,
    "Total Conversions": convertion,
    "Conversion Rate (%)": conversion_rate
})

# %%
print(result)
# Out:
#                   Total Users  Total Conversions  Conversion Rate (%)
# Location
# England                  1246                136            10.914928
# Northern Ireland         1242                103             8.293076
# Scotland                 1281                125             9.758002
# Wales                    1231                121             9.829407

# %%
#Identify users who spent more than 200 seconds on the site and viewed more than 5 pages.

# %%
 new_data=df[(df["Time Spent"] >= 200) & (df["Page Views"] >= 5)]
 new_data
# Out:
#       User ID Group  Page Views  Time Spent Conversion   Device  \
# 1       11682     A           9         342         No   Mobile
# 7       10041     B           9         292         No   Mobile
# 8       13191     B           8         434         No  Desktop
# 9       14427     B          12         271         No  Desktop
# 10      12776     A          14         351         No  Desktop
# ...       ...   ...         ...         ...        ...      ...
# 4994    14255     B          10         258         No  Desktop
# 4995    16360     B          12         313         No   Mobile
# 4996    18084     B          10         313         No  Desktop
# 4998    18647     B          13         346         No  Desktop
# 4999    16686     A          11         208         No  Desktop
#
#               Location
# 1             Scotland
# 7     Northern Ireland
# 8     Northern Ireland
# 9              England
# 10               Wales
# ...                ...
# 4994             Wales
# ...

# %%
 new_data["User ID"].count()
# Out:
# 2155
